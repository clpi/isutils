# %%
from lxml import etree as et, objectify as ob
from isu.models import Demo, Step, Audio 
from isu.operation.render import render_video, Format
from pathlib import Path
p = Path(r"C:\Users\Chris\d\Provision Resources on AWS with Terraform Using a Cloudformation Custom Resource [R1 - V4].demo")
demo = Demo(path=str(p))
dx = demo.root
# Out:
# Script failed to import. Cannot load Script file: Empty path. at location .

# %%
et.dump(dx, pretty_print=True)
# Out:
# <Demo xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
#   <ID>de95a428-ab4c-474f-ac1c-1222da7758b6</ID>
#   <DemoName>Custom Resource Type for Terraform</DemoName>
#   <Project>Unassigned Demos</Project>
#   <DemoVersion>1.0</DemoVersion>
#   <DemoSchemaVersion>1.1</DemoSchemaVersion>
#   <XmlName>
#     <Name><![CDATA[My Demo]]></Name>
#   </XmlName>
#   <WelcomeMessage/>
#   <Chapters>
#     <Chapter>
#       <ID>e7ea6b48-091c-4a64-a392-82fcd7dee90d</ID>
#       <XmlName>
#         <Name><![CDATA[Title Card]]></Name>
#       </XmlName>
#       <Steps>
#         <Step>
#           <ID>9b5d1c70-81b2-42d0-a855-6000c82716b6</ID>
#           <StartPicture xsi:type="StartPicture">
#             <PictureFile>Image_3.Png</PictureFile>
#             <Time>2020-02-13T13:14:46.5881337-08:00</Time>
#             <MouseCoordinates>
#               <X>960</X>
#               <Y>540</Y>
#             </MouseCoordinates>
# ...

# %%
from isu.ui.comp.prog import Progress 
from isu.operation.shell import Shell
from isu.operation.render import Render
from PyQt6.QtWidgets import QApplication
import sys

A = QApplication(sys.argv)
p = Progress(Shell, len=2, ix = 0)
p.show()
sys.exit(A.exec())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
